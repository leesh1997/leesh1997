# %% [markdown]
# # 유튜브 영상제목, 조회수 크롤링

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = wb.Chrome()
time.sleep(0.5)
driver.get("https://www.youtube.com/user/woowakgood/videos")
time.sleep(1)
body = driver.find_element_by_css_selector("body")

for i in range(10) :    
    body.send_keys(Keys.END)
    time.sleep(1)
    
title = driver.find_elements_by_id("video-title")
view = driver.find_elements_by_css_selector("#metadata-line > span:nth-child(1)")
for i in title :
    print(i.text)
for i in view :
    print(i.text)
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/2288657552.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/2288657552.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title = driver.find_elements_by_id("video-title")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/2288657552.py:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   view = driver.find_elements_by_css_selector("#metadata-line > span:nth-child(1)")
# 2021 왁튜브 인기동영상 TOP20
# 같이 자폭하기 #Shorts
# 한식 디저트 카페 꼬까자 - 마인크래프트 왁핑몰 17화
# 기억해줘 우왁굳 - 팬게임
# 문제 알고 있는 척 해야 됨 ㅋㅋㅋ - VR챗 스파이 게임
# 스팀게임 보다 재밌음 ㅋㅋㅋ - 슬레이 더 왁
# 징크스 vs 에코 - 마인크래프트 눕프로해커 "아케인" 편
# 고멤과 이세돌이 나오는 디펜스게임? 중독성 미쳤다 - 왁타펜스 (팬게임)
# 외국인들은 우왁굳에 대해 얼마나 알까? - (우왁굳 반응)
# 타임머신 개발에 성공했습니다 - VR챗 상황극
# 엄청나게 큰 컴퓨터 가게???? - 마인크래프트 왁핑몰 16화
# 왁생화 #Shorts
# 크리스마스편에 미니모르즈비가 치즐모드로 부활 했습니다
# 2021 우왁굳 크리스마스 캐롤 #Shorts
# 가상공간에서 학교를 다니게 된다면? - VR챗 학교 "미학 - 예술이 궁금하다"
# 자강두천 #Shorts
# 범인은 누구? - 크라임왁 2화 (완)
# 무지성 교배 게임 - 축산
# 야간순찰 '잭' 정체
# 가장 먼저 전투기 타기 #Shorts
# 야간 순찰 - VR챗 상황극
# 학익진 #Shorts
# 대머리에 이어서 바로 머리카락 ㅋㅋㅋㅋㅋㅋ 과연 맞출 수 있을까? - 고멤합방 "런닝맨 양세찬게임 2화" (완)
# 여자 초등학생이 생각하는 우왁굳 #Shorts
# 강도가 들었을 때 대처법 - 왁굳의 노가리
# 외나무다리 3:1 #Shorts
# 불 잘못 피우면 산불 나는 게임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ - 이카루스
# 살인사건이 발생했습니다 - 크라임왁 1화
# 이세계아이돌 (ISEGYE IDOL) - 리와인드 (RE:WIND) MV Teaser
# 400만 유튜버의 카메라맨이 되었습니다 - VR챗 상황극
# 개발자님 죄송합니다. 외국게임인 줄 알고 욕을 좀 했습니다... - ALT F4
# 주먹 피하기 #Shorts
# "가죽공방 아크팩토리" 실제 가게랑 120% 똑같네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그리고... - 마인크래프트 왁핑몰 15화
# 개같이 멸망 #Shorts
# 대머리한테 대머리 문제 내기 - 고멤합방 "런닝맨 양세찬게임"
# 이건 악의적으로 만든거지 솔직히 #Shorts
# 우승자 투표에서 역대급 사건이 일어났습니다 - 마인크래프트 눕프로해커 "고정멤버" 편
# 예상치 못한 기술 #Shorts
# 이제 참가자들이 아예 못찾는 수준으로 만들어옵니다... - VR챗 변신맨 최강팀전 2화
# 데이트를 위해 기다리는 남자 #Shorts
# 드디어 첫 점포 오픈! QCY, 111퍼센트 - 왁핑몰 14화
# 아니 맵을 이딴식으로 만들어 놓으면 ㅋㅋㅋㅋㅋㅋㅋ #Shorts
# 토토 사회실험
# 요네 추노컨 #Shorts
# 패션쇼 드디어 개최했습니다. 골반까지 깎는 장인의 등장?
# 배구 #Shorts
# 생애 첫 수면 내시경 썰 - 왁굳의 노가리
# 원반던지기 고수 #Shorts
# 속 개시원함 ㅋㅋㅋㅋ 쓸모없는 것을 너무 줄인 RPG
# 이게 사람이라고오오오오오? - 변신맨 최강팀전 1화
# 드래곤 토네이도 #Shorts
# 왁핑몰을 지어주신 분들에 대한 동상이 설치됩니다 - 마인크래프트 왁핑몰 13화
# 주식 떨어진거 걸렸을 때 하는 말 - 21년 10월 핫클립
# 오징어게임 영희 난이도가 더 높았다면 #Shorts
# 전사 궁수 도적 마법사 드루이드 - 마인크래프트 눕프로해커 "RPG 직업" 편
# 원래 안되는 건데 힘으로 되게 만드는 #Shorts
# 드디어 나오는 황금전사들! 그리고 두 농부의...- 마인크래프트 개미전쟁 5 : 진짜 황금시대
# 트롤링 나비효과 #Shorts
# 오징어게임 코인 제대로 탄 똥겜 ㅋㅋㅋ - 짭징어 게임 (CRAB GAME)
# 진짜 황금으로 떡칠 했습니다 - 개미전쟁 5 맵소개
# 옷 만들기 모드를 찾았습니다! 패션쇼 개최 삽가능 - 마인크래프트 패션쇼
# 아무도 예상 못한 스타트 #Shorts
# 손으로 만지기만 해도 죽을 수 있는 세상에서 가장 위험한 버섯 - 왁굳의 노가리
# 완벽한 착지 #Shorts
# 주작아니고 처음 해 보는데 바로 깨서 내가 더 놀람 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ - 포피 플레이타임
# 이게 성공한다고? #Shorts
# 이거 관종이라 일부러 이렇게 던지는건지 판단좀
# 저만 그런가요?
# 날아오는 자동차에 RPG 맞히기 ㅋㅋㅋㅋ #Shorts
# 1기 고멤에 탈락한 망령들이 할로윈에 초대를 보내왔습니다...
# 착지 실패 #Shorts
# 사라진 노예들 - 마인크래프트 왁핑몰 12화
# 믹서기 통과하기 #Shorts
# 드디어 대규모 공성전이 나왔습니다 - 마인크래프트 개미전쟁 4
# 호날두 호우 발음 하는 법 #Shorts
# 오징어게임을 이렇게 완벽하게 재현할 줄이야 - 마인크래프트
# GTA5 기차를 강제로 가속시키면? #Shorts
# 왁핑몰 광장을 만들 사람이 없네 - 마인크래프트 왁핑몰 11화
# 비행기 날개 위에서 #Shorts
# 네즈코... 일어나거라 - 마인크래프트 눕프로해커 "귀멸의칼날" 편
# 맵에 황금을 뿌렸습니다 - 마인크래프트 개미전쟁 4 황금시대 맵 미리보기
# 염소가 절벽을 타는 이유 - 왁굳의 노가리
# 한번도 못 맞추다가 바로 맞추는거 무엇 #Shorts
# 노예들이 반란을 준비하고 있었습니다 - 마인크래프트 왁핑몰 10화
# 오징어게임 재현률 미쳤습니다 ㅋㅋㅋ 영희 난이도 무엇
# 송도에서 세계를 구하다!?! - 마인크래프트 라스트쉘터
# GTA5 물리엔진 좋네 #Shorts
# 이 안에 사람이 있다고??????? 아니 이건 너무 하잖아 ㅋㅋㅋㅋ - VR챗 대규모 변신맨
# 임포스터가 미인계로 봐달라고 하면 먹힐까? - 어몽어스 이세돌 합방
# 장인어른의 음식을...
# 리자몽도 나옵니다 - 마인크래프트 눕프로해커 "불 포켓몬" 편
# 중앙 다이아를 차지하라! 역대급 공성전? - 마인크래프트 개미전쟁3
# 마인크래프트 오징어게임 예고편
# 09년도에 방송하다 신상털린 썰 - 왁굳의 노가리
# 공중에서 추월하기? #Shorts
# 수십명이 한 맵에 사물로 위장해 있다? - VR챗 대규모 변신맨
# 외나무다리에서 오토바이로 다 밀어버리기 #Shorts
# 가게는 터가 좋아야 하는데... 입점 룰렛! - 마인크래프트 왁핑몰 9화
# 오징어게임 패러디 - 왁징어게임 예고편
# 새로운 고멤들과의 첫 합방! - 양궁대결
# 감히 제드 앞에서 미드 케틀을 들어?
# 이미 7년전에 오징어게임을 한 사람이 있다? - GTA5 왁징어게임
# 우왁굳 피하기 (팬게임)
# 운 드럽게 없는 날 #Shorts
# 아내를 웃게하는 한마디 - 21년 8월 핫클립
# 자전거로 거의 90도 절벽 내려가기 #Shorts
# 곤충 못보시는 분들은 이번화는 거르세요. 그래도 해충은 안나옵니다. - 마인크래프트 눕프로해커 "곤충편"
# 바람개비 레이싱 #Shorts
# 이제 시작입니다. 입점 점포리스트 전부 공개! - 마인크래프트 왁핑몰 8화
# 개미전쟁 3 맵 패치내용 예고
# 미친사람들 총 출동 ㅋㅋㅋㅋㅋㅋㅋ 새로운 VR챗 고정멤버를 모집합니다. 고정멤버 시즌2. 쇼미더 고멤?
# 페널티킥 버그 레전드 ㅋㅋㅋㅋㅋㅋ #shorts
# 다음 중 한 사람을 꼭 죽여야 한다면 당신은 누구를 죽이시겠습니까? - VR챗 상황극
# 우왁굳 vs 비챤? 싸움에 휘말리는 멤버들.. 꼴등은 과연 누구? - 다이아 서바이벌 2화 (완)
# 트위치 vs 유튜브 #Shorts
# 마크로 본 서울 남산뷰 - 마인크래프트 치즐 건축콘테스트 "미술관 편"
# 아니 타격감이 콘솔 대전 게임 급인데? - 나의 히어로 아카데미아 : 최강 히어로
# VR챗에서 고멤들과 수동으로 ㅋㅋ 갈틱폰 하기 !
# 카이팅 레전드 #Shorts
# 중앙을 가로지르는 강이 생겼습니다 + 화공전략까지? - 마인크래프트 개미전쟁 2
# 이걸 맞네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ #Shorts
# 다이아 블록 9개를 먼저 만들어라! 꼴찌에겐 벌칙이?! - 다이아 서바이벌 1화
# 플래시맨 vs 헐크 #Shorts
# 갈틱폰 최고 난이도. 한 사람이 2장씩 그리는 "영화" 모드
# 죽음을 예견하고도 포기하지 않는 인천 간석동 정신 #Shorts
# 왁핑몰 정문 로고 부착 완료 ! - 마인크래프트 왁핑몰 7화
# 간식을 무서워하는 강아지 #Shorts
# 전세기 빌려서 초호화 여행 떠났습니다 - VR챗 상황극
# 고정멤버 최종합격해 울부짖는 시청자... #Shorts
# 레이저를 뚫고 보물을 훔쳐와야 하는데 풀트래커만이 할 수 있다?! - 고멤 합방
# 허리 디스크 한 번에 치료하는 법 #Shorts
# 40분 동안 팬치에게 미행당한 썰 - 왁굳의 노가리
# 자만은 방심을 부른다 #Shorts
# 와 진짜 농담아니고 군침돕니다 - 마인크래프트 눕프로해커 "음식" 편
# 침팬치 도미노 #Shorts
# 시청자들의 방을 훔쳐보는 컨텐츠 - 방물관
# 이걸 사네? #Shorts
# 통유리 안에 카페가 생겼어요 - 마인크래프트 왁핑몰 6화
# 만들라는 놀이공원은 안 만들고... #Shorts
# 작아져서 50 vs 50으로 전쟁하는 컨텐츠 - 마인크래프트 개미전쟁
# 이세돌 최종멤버를 골라주세요
# 대형 아이돌 기획사급 사옥이 생겼습니다 + 데뷔곡 살짝 공개? - 이세계 아이돌 Ep.4
# 사람이 이렇게 죽을 수도 있구나... #Shorts
# 고등학교 시절로 돌아갔습니다 - VR챗 상황극
# 탄창 방향까지 신경써야 되는 VR 총게임 #Shorts
# 고멤들과 저주받은 저택에 들어오게 되었습니다...
# 사람하고 싸우면 침팬치가 이기는 이유 #Shorts
# 풀트래커 끼고 시청자 패기 - 21년 7월 핫클립
# 소가 자동차 탈취하는 법 #Shorts
# 옥상 발코니 퀄리티 미쳤다 - 마인크래프트 왁핑몰 5화
# 배그에 나온 자율주행 차 #Shorts
# 극도로 부정적인 사람도 아이돌이 될 수 있나요? - 이세계 아이돌 Ep.3
# 와 나루토 구미모드!!!!!!!! 는 훼이크고 이번편 망해서 눕프핵 플러스로 개편 예정입니다 - 마인크래프트 눕프로해커 "나루토 편"
# 신작 mmorpg 나오자마자 다 무시하고 맵 여행 떠나기 - 블레스 언리쉬드
# 1화 조회수 100만 감사합니다! 이번엔 애니메이션을 해봤습니다 - 갈틱폰
# 토네이도 근처에 절대 가지 말아야 하는 이유 #Shorts
# 건콘 역사상 가장 큰 작품을 생일선물로 받았습니다 - 마인크래프트 치즐 건축콘테스트 "우왁굳의생일깜짝선물편"
# 대기전략 부시기 #Shorts
# 전직 아이돌 연습생이 참가했다? - 이세계 아이돌 Ep.2
# 정신병원 의사체험 - VR챗 상황극
# 헬기 탈 때 조심해야 되는 이유 #Shorts
# 우왁굳이 가장 뿌듯해 할 상황 월드컵
# 희생 플레이 #Shorts
# 눈뜨고 일어나니까 지구용사가 되어 있다면? - VR챗 상황극
# 폭죽 200개 한번에 터트리기 #Shorts
# 화장실의 저주 - 마인크래프트 왁핑몰 4화
# 배트맨 바이크 배트팟 소환 #Shorts
# GTA5로 알려주는 초보운전 주차 꿀팁. 딱 포인트만 정리 - 왁굳의 노가리
# 구사일생 - GTA5 #Shorts
# 돈 없어서 고멤 발 핥았습니다
# 오디션 중에 엄크 뜸 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ #Shorts
# 오디션 도중에 엄크 뜸 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ- 이세계 아이돌 Ep.1
# 시청자가 도방할 때 대처법 #Shorts
# 아니 외국판 캐치마인드 개 웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ - 갈틱폰
# 데드 아티스트 - GTA5 #Shorts
# 배틀크루져 크기 뭐야?? - 마인크래프트 치즐 건축 콘테스트 "스타 2편"
# 다리위에서 밀어서 떨어뜨리기 - GTA5 #Shorts
# 백수가 된 노동자들 - 마인크래프트 왁핑몰 3화
# 먼저 시동걸어서 박아버리는 게임 - GTA5 #Shorts
# FPS처럼 하는 마피아게임이 있다?
# 바둑 둘 때 "금기어" #Shorts
# 저음역대 사람은 못하는 게임 #Shorts
# 배그 한국맵 나옴. 오랜만에 추억의 겜스터 멤버들과...
# 보드 타는 걸 방해하는 사람때문에... - GTA5 #Shorts
# 초사이어인 1,2,3로 변하는 손오공 - 눕프로해커 드래곤볼 편
# 아이즈원 편곡가 합류?!! - 이세계 아이돌 EP.0 (prologue)
# 스타1이 갓겜인 이유 - 마인크래프트 치즐 건축 콘테스트 "스타1 편" 1화
# 한국에 존재하는 지브리의 한 장면 같은 곳 #Shorts
# 내 영상 클릭하지 말라고 말했다 다들명심해 ! 제발 말 좀 들으세요... ♥
# 군필특 #Shorts
# 아무리 무서운 공포게임이라도 4명이서 한다면 무섭지 않다?
# 목 긁어달라고 명령하는 강아지 #Shorts
# 공포게임 못하는 사람 억지로 하게 만드는 방법 (고멤 합방 예고편) #Shorts
# 게임 설치 하나 제대로 못하는 스트리머
# 사람은 2명, 총은 1개 #Shorts
# 외벽유리 + 정문 + 주차장 까지 기초 공사 완료! - 마인크래프트 왁핑몰 2화
# 맥도날드 노래 자세히는 모르는 사람 #Shorts
# 생존게임이 로그라이크라니
# 죽이고 보니 300만 유튜버 #Shorts
# 진화할 수록 고수가 건축합니다. - 마인크래프트 눕프로해커 "물포켓몬" 편
# 만져도 계속 자는 고양이 #Shorts
# 단서만 보고 보물찾기. 무려 8인 멀티?
# 마인크래프트에서 캐릭터가 원자만큼 작아진다면?
# (장난아님) 당신을 버츄얼 아이돌로 만들어 드립니다
# 100명이서 동시에 연주하는 게임. 팬치들의 단합심에 놀랐습니다.
# 일본에서 맞은 썰 - 왁굳의 노가리
# 아내에게 리얼 레이싱 시뮬레이터를 시켜 보았습니다 - 아이레이싱
# 마크에서 쇼핑몰 만들어서 실제 기업들 유치 시키는 컨텐츠 - 왁핑몰 1화
# 왕이 되어 신하들 상소문 받는 게임. 신하들 전부 사람임 ㅋㅋㅋ
# 수학이 어려운 이유 - 왁굳의 노가리 볶음밥
# 시청자들로 경마 시키는 팬게임이 나왔습니다 ㅋㅋㅋㅋㅋㅋㅋ
# 초보 중수 고수의 실력을 비교하는 컨텐츠 - 마인크래프트 눕프로해커 "롤 챔피언 편"
# 래퍼 벤젠프로가 팬치라고? - 21년 5월 핫클립 모음집
# 초대형 비요뜨 등장 ㅋㅋㅋㅋ - 마인크래프트 치즐 건축 콘테스트 "브랜드" 편
# 순진하다고 믿었던 고멤에게 속았습니다
# 괴물들의 음식을 만들어 주는 요리사 되는 게임
# 어몽어스 VR로 하니까 훨씬 재밌음 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 여자들은 왜 너드남을 좋아하는걸까 - 왁굳의 노가리
# 13년차 인터넷 방송인의 악플을 대하는 자세 - 왁굳의 노가리
# 여자들이 싫어하는 남자 - 왁굳의 노가리
# 여자 100명하고 소개팅 하는 컨텐츠
# 미소녀 + 로봇 = 파이널 기어
# 곤충 못보면 절대 클릭하지 마시오. 마크라고 무시하면... - 마인크래프트 치즐 건축콘테스트 '극혐편 2화'
# 고릴라 술래잡기
# "마인크래프트 왁빌딩" 에 입점하실 소상공인 점주분들을 모집합니다
# 10덕 만화보다 아내에게 들켰습니다
# 뱅갈고무나무 샀습니다
# 고멤들만 모아놨더니 진짜 가슴이 웅장해진다 ㅋㅋㅋㅋㅋㅋㅋㅋ
# 똥 냄새 주의 - 마인크래프트 치즐 건축 콘테스트 '극혐 상편'
# 왁파고의 등장 - 고정멤버 정식면접 B조
# 퇴근한 아내에게 라면 끓여 달라고 하기 - 21년 4월 핫클립
# 의자 시뮬레이터
# 고정멤버 정식면접 A조
# 인간이길 포기한 그들.. VR챗 풀트래커 동물원?
# 고수를 못 먹는 사람들에게... - 왁굳의 노가리
# 시청자들의 연봉을 알아보았습니다
# 우왁굳 고정멤버 시즌2 - 완전히 새로운 가상세계 컨텐츠 "왁타버스"
# 쉑쉑버거 에서 익숙한 냄새가? 신제품! 치폴레 체다 버거 먹방
# 2021 왁두 아바타를 선물 받았습니다
# 계란 떨어뜨리면 터지는 게임
# 리제로 렘 vs 레옹 마틸다 - 마인크래프트 치즐 건축콘테스트 "히로인편"
# 이제 중국게임 수준 무시 못하겠네요...
# 일본여자가 한국남자를 선택할까?
# RTX 3080을 붙일수있는 노트북이 있다?
# 1대 100 소개팅. 여자가 1
# 한호흡 챌린지 : 13년차 스트리머 vs 전 아나운서 현 캐스터
# GTA6 : 애님맬고
# 당신이 절대 모를 우왁굳에 대한 22가지 사실
# 미친여자
# 노조가 파업했습니다. - 마인크래프트 왁파트 18화 (마지막화)
# 나 조커 안 좋아하는데 연출 뭐야 찢었다... - 마인크래프트 치즐 건축콘테스트 "장소 후편"
# 귀멸의 칼날에 나오는 우로코다키의 집 - 마인크래프트 치즐 건축콘테스트 "장소 전편"
# 제 나무위키를 보았습니다
# 외국인들에게 납치당했습니다
# 결승전 개 빡세네 찾을 때 까지 켠왕한다 - VR챗 즉석변신맨 3화 (완)
# 당신에게 1억이 있다면 무슨 차를 사실겁니까? - 설문놀이
# 1대1 총게임을 만들었다고? 근데 왜 재밌지?
# 어이가 없어서 헛웃음 나오는 팬게임
# 왁.두.퍼.즐
# 아 이게 사람이었다고? ㅋㅋㅋㅋㅋ - VR챗 즉석변신맨 2화
# 전 고멤이 흑화한 이유는?
# 이게 마크 그래픽이라고???? 연출 기법 미쳤다 ㅋㅋㅋㅋㅋㅋㅋ - 마인크래프트 치즐 건축콘테스트 "무기"편
# 주식으로 돈 날린거 걸렸습니다 - 왁굳의 노가리 (Prod. Pr!d3)
# 계란 떨어뜨리면 안되는 게임. 떨어지면 어떻게 되냐면...
# 사물로 변해서 사람 아닌척 하기 ㅋㅋㅋㅋㅋ - VR챗 즉석변신맨
# 기술 쓰자마자 터짐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 정신나간 배틀로얄 게임
# 유튜버로 성공하기 위해 가장 중요한 것은 무엇일까? - 설문놀이
# 결혼할 때 개 극혐이었던 썰 - 왁굳의 노가리
# 아니 심영 개 똑같네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ - 마인크래프트 치즐 건축콘테스트 "조연" 편
# 사실은 차 부시라고 만든 게임
# 동물을 치료하는 수의사가 되는 게임. 그런데...
# 벤츠 vs BMW vs 아우디 vs 현대 - 마인크래프트 배틀건콘
# 이 섬 사람들은 왜 100살 넘게 사는걸까요...? - VR챗 상황극 "장수섬의 비밀"
# 단지내 메타세콰이어 길을 만들었습니다 - 왁파트 17화
# 이게 메타버스의 미래? 3D 박물관을 만들 수 있네요 - VR챗 신맵탐방
# 에이 토마토맛 컵라면이 어딨어~ 응? 있네? - 닛신 칠리 토마토
# 인간이 말이라고? - 우마무스메 (말딸)
# 네스호의 괴물을 아십니까? - 21년 2월 핫클립
# 계란팔고 소젖짜서 돈버는 목장 시뮬레이터 게임
# 트롤과의 사투 - 발헤임 4화
# 상황에 맞는 음식 월드컵
# 동물들을 건콘에서 표현할 수 있을까? - 마인크래프트 치즐 건축콘테스트 '동물 편'
# 마요네즈가 들어있는 야키소바 컵라면이 있다? - 잇페이짱
# 낯선 곳에 치킨 배달을 가게 되었습니다... - VR챗 상황극 근본치킨
# 킹콩 vs 인간 300명 승자는?
# 다른 여자랑 데이트하다 걸렸습니다 - 21년 1월 핫클립
# 아니 얼마나 빡치게 할라고 게임 이름이 ALT F4야
# 원펀맨으로 경기장을 부숴버린 역대급 연출 - 마인크래프트 치즐 건축 콘테스트 '피규어 편'
# 아니 이게 컵라면 국물 맛이라고? - 아사히카와 돈코츠 시오 라멘
# 집 안에 영화관이 있다?? - 마인크래프트 왁파트 16화
# 찍어만 먹으려고 했는데 생각보다 맛있는데? - 로얄크라운
# 코난이 되어 살인범을 찾아야 한다. 게다가 참가자들도 서로 범인을 모르는 상황에서 만들어졌다고???? - VR챗 상황극
# 유튜버 입덕 공감툰
# 주식했다 개 망했습니다
# 치킨 vs 피자 - 마인크래프트 배틀건콘
# 아나콘다 vs 익룡 개레전드 명장면 나옵니다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ -애니멀 리볼트 배틀 시뮬레이터
# 감자칩이 와사비 맛이라고? - 와사비후
# 세상의 모든 괴물들 총집합?! - 마인크래프트 치즐 건축콘테스트 '괴물'편
# 리얼한 먹방이 나옵니다 주의 - 왁물원 8화
# 검은숲으로 (동료 천양 참전) - 발헤임 3화
# 소심한 사람이 미용실 갔을 때 - 왁툰
# 100명의 시청자를 속인 마인크래프트 대운동회
# 콩고기로 만든 버거가 맛있을까? - 버거킹 플랜트 와퍼
# 애착 이불을 23년동안 썼다는게 말이 돼? - 나만 가지고 있는 물건 콘테스트
# 본인이 객관적이라고 생각하시나요? - 왁굳의 노가리
# 원피스 vs 나루토 - 마인크래프트 배틀 건콘
# 실수로 봉인된 보스 소환함 ㅋㅋㅋㅋㅋ - 발헤임 2화
# 아니 컵라면인데 차슈에 김까지 들어간다고?? - 닛신 라오 간장라면
# 초보운전시절 어리버리 탔었던 썰 - 왁굳의 노가리
# 이제 내가 썸네일 만들어야지
# 새로운 마크 컨텐츠를 만들어 왔습니다 - 배틀건콘
# 젤다 야숨을 뛰어 넘는 갓겜이 나왔습니다 - 발헤임
# 엄청나게 큰 유부가 들어있는 컵라면이 있다? - 닛신 키츠네 돈베이 우동
# 분양 사기 사건 발생? - 마인크래프트 왁파트 15화
# 사람이 공룡을 때려잡을 수 있을까? - 애니멀 리볼트 배틀시뮬레이터
# 100가지의 목소리변조가 가능한 프로그램? 성능 미쳤음 ㅋㅋㅋㅋㅋ
# 3D펜 장인 300만 유튜버 '사나고' 님을 인터뷰 하였습니다
# 온 세상 로봇들 다 출동 했네 ㅋㅋㅋㅋ - 마인크래프트 치즐 건축콘테스트 '로봇' 편
# 그랑사가 100만원 어치 가챠 하기
# 왁준 - 귀역왁 21년 1월호
# 녹차맛 쿠키가 과연 맛있을까?
# 심해 공포증 있는 사람은 못하는 게임. 바다 속으로 들어갑니다
# 이런 MMORPG 가 나왔으면 좋겠다
# 시청자들의 직업을 알아 보았는데 .. 상상도 못한 직업들이??
# 100엔짜리 카레라면 건더기 미쳤습니다 - 닛신 컵누들 커리
# 드디어 지하주차장에 자동차들이 ?! - 마인크래프트 왁파트 14화
# 10000원짜리 인스턴트 카레는 뭐가 다를까? - 사가현산 와규 카레
# 건콘 역사상 역대급 건축물이 나왔습니다 - 마인크래프트 치즐 건축콘테스트 '브랜드 매장 (프랜차이즈)' 2화 (완)
# 컴퓨터가 멈춘다?!
# 여고생 인터뷰 (공감툰 소재 모으기)
# 조회수 22만회
# 조회수 12만회
# 조회수 29만회
# 조회수 29만회
# 조회수 45만회
# 조회수 44만회
# 조회수 59만회
# 조회수 34만회
# 조회수 24만회
# 조회수 35만회
# 조회수 44만회
# 조회수 34만회
# 조회수 41만회
# 조회수 20만회
# 조회수 25만회
# 조회수 36만회
# 조회수 39만회
# 조회수 36만회
# 조회수 25만회
# 조회수 35만회
# 조회수 88만회
# 조회수 23만회
# 조회수 38만회
# 조회수 56만회
# 조회수 52만회
# 조회수 36만회
# 조회수 40만회
# 조회수 63만회
# 조회수 49만회
# 조회수 30만회
# 조회수 47만회
# 조회수 19만회
# 조회수 53만회
# 조회수 37만회
# 조회수 53만회
# 조회수 37만회
# 조회수 59만회
# 조회수 78만회
# 조회수 36만회
# 조회수 20만회
# 조회수 51만회
# 조회수 60만회
# 조회수 28만회
# 조회수 24만회
# 조회수 43만회
# 조회수 21만회
# 조회수 39만회
# 조회수 18만회
# 조회수 42만회
# 조회수 43만회
# 조회수 46만회
# 조회수 46만회
# 조회수 35만회
# 조회수 34만회
# 조회수 55만회
# 조회수 105만회
# 조회수 43만회
# 조회수 56만회
# 조회수 34만회
# 조회수 17만회
# 조회수 37만회
# 조회수 107만회
# 조회수 57만회
# 조회수 32만회
# 조회수 70만회
# 조회수 150만회
# 조회수 39만회
# 조회수 52만회
# 조회수 43만회
# 조회수 35만회
# 조회수 24만회
# 조회수 61만회
# 조회수 88만회
# 조회수 52만회
# 조회수 48만회
# 조회수 170만회
# 조회수 83만회
# 조회수 57만회
# 조회수 28만회
# 조회수 105만회
# 조회수 26만회
# 조회수 52만회
# 조회수 70만회
# 조회수 65만회
# 조회수 79만회
# 조회수 35만회
# 조회수 63만회
# 조회수 65만회
# 조회수 57만회
# 조회수 59만회
# 조회수 99만회
# 조회수 50만회
# 조회수 24만회
# 조회수 42만회
# 조회수 125만회
# 조회수 58만회
# 조회수 83만회
# 조회수 68만회
# 조회수 36만회
# 조회수 34만회
# 조회수 41만회
# 조회수 35만회
# 조회수 44만회
# 조회수 223만회
# 조회수 53만회
# 조회수 274만회
# 조회수 88만회
# 조회수 42만회
# 조회수 93만회
# 조회수 21만회
# 조회수 72만회
# 조회수 112만회
# 조회수 89만회
# 조회수 52만회
# 조회수 72만회
# 조회수 76만회
# 조회수 22만회
# 조회수 40만회
# 조회수 66만회
# 조회수 58만회
# 조회수 259만회
# 조회수 54만회
# 조회수 182만회
# 조회수 140만회
# 조회수 59만회
# 조회수 69만회
# 조회수 44만회
# 조회수 33만회
# 조회수 87만회
# 조회수 46만회
# 조회수 98만회
# 조회수 47만회
# 조회수 75만회
# 조회수 115만회
# 조회수 62만회
# 조회수 91만회
# 조회수 262만회
# 조회수 59만회
# 조회수 76만회
# 조회수 79만회
# 조회수 56만회
# 조회수 41만회
# 조회수 109만회
# 조회수 53만회
# 조회수 62만회
# 조회수 56만회
# 조회수 142만회
# 조회수 40만회
# 조회수 197만회
# 조회수 73만회
# 조회수 68만회
# 조회수 48만회
# 조회수 84만회
# 조회수 34만회
# 조회수 128만회
# 조회수 365만회
# 조회수 105만회
# 조회수 174만회
# 조회수 67만회
# 조회수 104만회
# 조회수 62만회
# 조회수 46만회
# 조회수 46만회
# 조회수 147만회
# 조회수 58만회
# 조회수 64만회
# 조회수 34만회
# 조회수 59만회
# 조회수 65만회
# 조회수 63만회
# 조회수 122만회
# 조회수 110만회
# 조회수 78만회
# 조회수 178만회
# 조회수 29만회
# 조회수 68만회
# 조회수 377만회
# 조회수 104만회
# 조회수 57만회
# 조회수 56만회
# 조회수 132만회
# 조회수 159만회
# 조회수 38만회
# 조회수 420만회
# 조회수 95만회
# 조회수 60만회
# 조회수 69만회
# 조회수 29만회
# 조회수 69만회
# 조회수 202만회
# 조회수 127만회
# 조회수 47만회
# 조회수 59만회
# 조회수 53만회
# 조회수 34만회
# 조회수 86만회
# 조회수 234만회
# 조회수 29만회
# 조회수 368만회
# 조회수 108만회
# 조회수 41만회
# 조회수 48만회
# 조회수 65만회
# 조회수 28만회
# 조회수 68만회
# 조회수 47만회
# 조회수 39만회
# 조회수 105만회
# 조회수 112만회
# 조회수 40만회
# 조회수 44만회
# 조회수 89만회
# 조회수 52만회
# 조회수 117만회
# 조회수 73만회
# 조회수 29만회
# 조회수 60만회
# 조회수 81만회
# 조회수 45만회
# 조회수 81만회
# 조회수 35만회
# 조회수 12만회
# 조회수 75만회
# 조회수 26만회
# 조회수 30만회
# 조회수 67만회
# 조회수 44만회
# 조회수 95만회
# 조회수 81만회
# 조회수 66만회
# 조회수 78만회
# 조회수 28만회
# 조회수 64만회
# 조회수 72만회
# 조회수 62만회
# 조회수 99만회
# 조회수 58만회
# 조회수 29만회
# 조회수 27만회
# 조회수 22만회
# 조회수 101만회
# 조회수 28만회
# 조회수 49만회
# 조회수 17만회
# 조회수 56만회
# 조회수 80만회
# 조회수 36만회
# 조회수 55만회
# 조회수 38만회
# 조회수 80만회
# 조회수 176만회
# 조회수 114만회
# 조회수 91만회
# 조회수 37만회
# 조회수 44만회
# 조회수 49만회
# 조회수 41만회
# 조회수 54만회
# 조회수 23만회
# 조회수 67만회
# 조회수 82만회
# 조회수 108만회
# 조회수 81만회
# 조회수 32만회
# 조회수 71만회
# 조회수 92만회
# 조회수 30만회
# 조회수 86만회
# 조회수 128만회
# 조회수 39만회
# 조회수 23만회
# 조회수 34만회
# 조회수 183만회
# 조회수 68만회
# 조회수 21만회
# 조회수 35만회
# 조회수 56만회
# 조회수 29만회
# 조회수 28만회
# 조회수 27만회
# 조회수 32만회
# 조회수 55만회
# 조회수 58만회
# 조회수 93만회
# 조회수 54만회
# 조회수 68만회
# 조회수 74만회
# 조회수 100만회
# 조회수 68만회
# 조회수 62만회
# 조회수 16만회
# 조회수 104만회
# 조회수 33만회
# 조회수 63만회
# 조회수 61만회
# 조회수 75만회
# 조회수 36만회
# 조회수 121만회
# 조회수 108만회
# 조회수 34만회
# 조회수 41만회
# 조회수 89만회
# 조회수 33만회
# 조회수 183만회
# 조회수 52만회
# 조회수 65만회
# 조회수 42만회
# 조회수 60만회
# 조회수 38만회
# 조회수 36만회
# 조회수 68만회
# 조회수 64만회
# 조회수 63만회
# 조회수 80만회
# 조회수 55만회
# 조회수 59만회
# 조회수 58만회
# 조회수 90만회
# 조회수 25만회
# 조회수 27만회
# 조회수 25만회
# 조회수 58만회
# 조회수 39만회
# 조회수 156만회
# 조회수 69만회
# 조회수 106만회
# 조회수 56만회
# 조회수 94만회
# 조회수 48만회
# 조회수 30만회

# %%
driver = wb.Chrome()
driver.get("https://www.youtube.com/user/woowakgood/videos")

# %%
title = driver.find_elements_by_id("video-title")
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/2887971732.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title = driver.find_elements_by_id("video-title")

# %%
for i in title :
    print(i.text)
# Out:
# 2021 왁튜브 인기동영상 TOP20
# 같이 자폭하기 #Shorts
# 한식 디저트 카페 꼬까자 - 마인크래프트 왁핑몰 17화
# 기억해줘 우왁굳 - 팬게임
# 문제 알고 있는 척 해야 됨 ㅋㅋㅋ - VR챗 스파이 게임
# 스팀게임 보다 재밌음 ㅋㅋㅋ - 슬레이 더 왁
# 징크스 vs 에코 - 마인크래프트 눕프로해커 "아케인" 편
# 고멤과 이세돌이 나오는 디펜스게임? 중독성 미쳤다 - 왁타펜스 (팬게임)
# 외국인들은 우왁굳에 대해 얼마나 알까? - (우왁굳 반응)
# 타임머신 개발에 성공했습니다 - VR챗 상황극
# 엄청나게 큰 컴퓨터 가게???? - 마인크래프트 왁핑몰 16화
# 왁생화 #Shorts
# 크리스마스편에 미니모르즈비가 치즐모드로 부활 했습니다
# 2021 우왁굳 크리스마스 캐롤 #Shorts
# 가상공간에서 학교를 다니게 된다면? - VR챗 학교 "미학 - 예술이 궁금하다"
# 자강두천 #Shorts
# 범인은 누구? - 크라임왁 2화 (완)
# 무지성 교배 게임 - 축산
# 야간순찰 '잭' 정체
# 가장 먼저 전투기 타기 #Shorts
# 야간 순찰 - VR챗 상황극
# 학익진 #Shorts
# 대머리에 이어서 바로 머리카락 ㅋㅋㅋㅋㅋㅋ 과연 맞출 수 있을까? - 고멤합방 "런닝맨 양세찬게임 2화" (완)
# 여자 초등학생이 생각하는 우왁굳 #Shorts
# 강도가 들었을 때 대처법 - 왁굳의 노가리
# 외나무다리 3:1 #Shorts
# 불 잘못 피우면 산불 나는 게임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ - 이카루스
# 살인사건이 발생했습니다 - 크라임왁 1화
# 이세계아이돌 (ISEGYE IDOL) - 리와인드 (RE:WIND) MV Teaser
# 400만 유튜버의 카메라맨이 되었습니다 - VR챗 상황극

# %%
view = driver.find_elements_by_css_selector("#metadata-line > span:nth-child(1)")
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/2713148463.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   view = driver.find_elements_by_css_selector("#metadata-line > span:nth-child(1)")

# %%
for i in view :
    print(i.text)
# Out:
# 조회수 22만회
# 조회수 12만회
# 조회수 29만회
# 조회수 29만회
# 조회수 45만회
# 조회수 44만회
# 조회수 59만회
# 조회수 34만회
# 조회수 24만회
# 조회수 35만회
# 조회수 44만회
# 조회수 34만회
# 조회수 41만회
# 조회수 20만회
# 조회수 25만회
# 조회수 36만회
# 조회수 39만회
# 조회수 36만회
# 조회수 25만회
# 조회수 35만회
# 조회수 88만회
# 조회수 23만회
# 조회수 38만회
# 조회수 56만회
# 조회수 52만회
# 조회수 36만회
# 조회수 40만회
# 조회수 63만회
# 조회수 49만회
# 조회수 30만회

# %%
len(title)
# Out:
# 360

# %%
# 스크롤 하는 방법

# %%
body = driver.find_element_by_css_selector("body")
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/365464818.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")

# %%
body.send_keys(Keys.END)

# %% [markdown]
# #  Gmarket 베스트 수집 ★

# %%
import pandas as pd

# %%
options = wb.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

# %%
driver = wb.Chrome("C:/Users/smhrd/크롤링(박병관)/chromedriver.exe", options = options)
time.sleep(0.5)
driver.get("http://corners.gmarket.co.kr/Bestsellers")
time.sleep(0.5)
titleList = []
priceList = []
for i in range(3) :
    img = driver.find_elements_by_css_selector("img.lazy")
    img[i].click()
    time.sleep(1)
    title = driver.find_element_by_css_selector(".itemtit")
    price = driver.find_element_by_css_selector(".price_real")
    # 순수한 글자정보만 저장해주는 리스트 작업
    titleList.append(title.text)
    priceList.append(price.text)
    driver.back()
    time.sleep(1)
dic = {"상품명" : titleList, "가격" : priceList}
gmarket = pd.DataFrame(dic)
gmarket
gmarket.to_csv("지마켓.csv", encoding="euc-kr")

# 데이터프레임 제작
# csv형식으로 저장
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/1303170270.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome("C:/Users/smhrd/크롤링(박병관)/chromedriver.exe", options = options)
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/1303170270.py:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   img = driver.find_elements_by_css_selector("img.lazy")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/1303170270.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   title = driver.find_element_by_css_selector(".itemtit")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_12296/1303170270.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price = driver.find_element_by_css_selector(".price_real")

# %%
gmarket
# Out:
#                                        상품명       가격
# 0       (21년산/삼광/특) 아산맑은쌀 삼광 10KG 쿠폰32850원  37,130원
# 1        탐라 제주 흙감자 감자 5kg(중) / 22년 첫수확 햇감자  11,000원
# 2  세제 1.5(리)4개+800(세or유)2팩+세제50ml+샤세2종Q222  15,400원
# 3                 해피바스 로즈 에센스바디워시 900G x4개  16,900원
# 4        한라봉 2kg 중과엄선 8-10과(2개구매시 4.5kg발송)  15,900원
# 5               지리산흑돼지 찹쌀 탕수육 눈꽃까망 1kg+1kg  14,500원
# 6     시매쓰 빨라지고 강해지는 이것이 연산이다 A~F단계 세트 선택구매  26,120원
# 7                  BYO 식물성유산균 100억 30포 x3개  22,320원
# 8                              진라면 매운맛 40봉  20,900원
# 9       손질 없이 간편한 해물모듬 600gx4봉 /18810원 쿠폰가  20,900원
